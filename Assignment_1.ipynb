# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.

# %% [markdown]
# Ans)
# ##### * : operators
# ##### 'hello' : values
# ##### -87.8 : values
# ##### - : operators
# ##### / : operators
# ##### + : operators
# ##### 6 : values

# %% [markdown]
# What is the difference between string and variable?

# %% [markdown]
# Ans)

# %%
name = "List"
type(name)
# name is variable which store the value [eg: name]
# string is data type of value that is store in variable [eg: "List" is string]
# Out:
# str

# %% [markdown]
# Describe three different data types.

# %% [markdown]
# Ans)

# %%
name = "List" # it is sequence of characters inclosed in quotes ["String"]
print(type(name))
number = 10  # it is number without fractional part ["Integer"]
print(type(number))
decimal = 10.5 # it is number with fractional part ["Float"]
print(type(decimal))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# What is an expression made up of? What do all expressions do?

# %% [markdown]
# Ans) expression: expression is made up of operators and operands which later evaluted as some value or
#   expression is representation of value in the form of operators and operands

# %% [markdown]
# This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?

# %% [markdown]
# Ans) expression: expression is made up of operators and operands
# statement in like command for programming language to execute when, where, how etc.
# [eg: spam=10 is statement which telling compiler to assigne the value 10 to the variable spam]

# %% [markdown]
# After running the following code, what does the variable bacon contain?
# ##### bacon = 22
# ##### bacon + 1

# %% [markdown]
# Ans)

# %%
bacon = 22  # assign value to variable
print(bacon)
bacon+1 # add 1 to bacon wit not reassign the value of bacon
# Out:
# 22
# 23

# %% [markdown]
# What should the values of the following two terms be?
# ##### "spam" +"spamspam"
# ##### "spam"* 3

# %% [markdown]
# Ans) both output will we same

# %%
"spam"+"spamspam"
# Out:
# 'spamspamspam'

# %%
"spam"*3
# Out:
# 'spamspamspam'

# %% [markdown]
# Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# Ans) there is set of rule for valid variable name
#  1. variable name start with "_" alphabet character
#  2. only "_" is allowed no special character is allowed
#  3. connot start with number
#  4. number can be add in middle or end of variable name
# - eggs is valid variable name
# - 100 is invalid variable name because it starts with number

# %% [markdown]
# What three functions can be used to get the integer, floating-point number, or string
# version of a value?

# %% [markdown]
# Ans)
# - int()
# - float()
# - str()

# %% [markdown]
# Why does this expression cause an error? How can you fix it?
# - &#39;I have eaten &#39; + 99 + &#39; burritos.&#39;

# %%
"I have eaten " + "99" + " burritos."
# Out:
# 'I have eaten 99 burritos.'
